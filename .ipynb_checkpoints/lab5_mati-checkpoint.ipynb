# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import MaxAbsScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import FactorAnalysis

df = pd.read_excel ('bearing-unsup.xlsx')
display(df)
X_conAnomalias = np.array(df)
# Out:
#       Unnamed: 0        rps       p2p       std       kurt      entro  \
# 0              0  14.307969  0.034390  0.003851   0.713983  14.106049
# 1              1  15.024038  0.033479  0.004023   0.241707  14.191996
# 2              2  15.024038  0.031518  0.004195   0.132659  14.199525
# 3              3  15.578686  0.033915  0.004205   0.267163  14.180472
# 4              4  16.276042  0.029362  0.004354  -0.012080  14.242593
# ...          ...        ...       ...       ...        ...        ...
# 2995        2995  21.701389  0.553307  0.029428  19.559926  12.320488
# 2996        2996  21.701389  0.559233  0.022701  23.230680  12.744078
# 2997        2997  21.701389  0.751598  0.028305  33.674119  12.102589
# 2998        2998  21.909674  0.559624  0.029708  17.693031  12.659644
# 2999        2999  23.688826  0.656259  0.032807  19.572454  12.390375
#
#           crest  skewness     cenfreq        stdfreq  domfreq
# 0      4.790768  0.046665  3419.720323   7775.145046     4955
# 1      4.619703 -0.136264  3538.439582   8322.224662     4955
# 2      3.935607  0.026957  3325.971210   7672.572125     4955
# 3      4.042173 -0.054884  2496.585106   3596.784408     4955
# 4      3.620787  0.048537  3607.763602   8562.095291     4955
# ...         ...       ...          ...           ...      ...
# 2995   9.943409  0.141315  3025.695834   4877.364036     1120
# 2996  12.554286 -0.292716  4927.933014  11458.398483     1595
# 2997  14.342625 -0.082989  4892.559843  11078.956062     1145
# 2998   9.466071 -0.119495  3356.100238   7077.069023     1155
# 2999  10.221065  0.133762  3484.437312   7353.569467     1130
#
# [3000 rows x 11 columns]

# %% [markdown]
# ### Ejercicio 1

# %%
clf = OneClassSVM(kernel='rbf', nu=0.033).fit(X_conAnomalias)
y_predict = clf.predict(X_conAnomalias)

X = X_conAnomalias[y_predict == 1]

# %% [markdown]
# ### Ejercicio 2

# %%
scaler = MaxAbsScaler().fit(X)
X_scaled = scaler.transform(X)

pca = PCA(n_components=3)
X_p = pca.fit(X_scaled)
X_p = pca.transform(X_scaled)

fig = plt.figure()
fig.set_size_inches(8,6)
ax = fig.add_subplot(projection='3d')
ax.scatter(X_p[:, 0], X_p[:, 1], X_p[:, 2])
ax.set_xlabel("Atributo 1 PCA"), ax.set_ylabel("Atributo 2 PCA"), ax.set_zlabel("Atributo 3 PCA")
plt.show()

fa = FactorAnalysis(n_components=3)
X_f = fa.fit(X_scaled)
X_f = fa.transform(X_scaled)

fig = plt.figure()
fig.set_size_inches(8,6)
ax = fig.add_subplot(projection='3d')
ax.scatter(X_f[:, 0], X_f[:, 1], X_f[:, 2])
ax.set_xlabel("Atributo 1 FA"), ax.set_ylabel("Atributo 2 FA"), ax.set_zlabel("Atributo 3 FA")
plt.show()

# En las figuras se visualiza que se tiene una mejor agrupacion de datos respecto a sus caracteristicas en PCA que en FA, 
# ya que en la segunda mencionada no se diferencian agrupaciones entre si.

# %% [markdown]
# ### Ejercicio 3
